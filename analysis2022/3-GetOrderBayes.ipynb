# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

from matplotlib.colors import LogNorm
from scipy.integrate import odeint
sns.set_context("talk", font_scale=1.4)


# for using LaTeX fonts
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %% [markdown]
# ### Get order with pathpy

# %%
import pathpy as pp

# %% [markdown]
# ## Try it for the real data

# %%
# load the Polity5 data from the excel data frame
timeSeries = pd.read_excel('./../data/polity5/p5v2018.xls')
# do some cleaning
timeSeries = timeSeries.dropna(subset=['year', 'country', 'polity2'])

timeSeries = timeSeries[timeSeries["polity2"] != -66]
timeSeries = timeSeries[timeSeries["polity2"] != -88]

# %%
def pathFromTimeSeries(timeSeriesIn):

    paths = pp.Paths()
    

     # split the timeseries into one for each country 
    uniqueCountries = timeSeriesIn['country'].unique()
    countryTimeseries =[]


    for country in uniqueCountries:
        sortedPolity2Country = timeSeriesIn[timeSeriesIn['country'] == country].sort_values(by='year')["polity2"].tolist()
        
        #print(tuple(sortedPolity2Country))

        paths.add_path(tuple(sortedPolity2Country))
        
        #break
        #T=len(sortedPolity2Country)# number of data points
    
    return(paths)

# %%
polity2Path = pathFromTimeSeries(timeSeries)

# %%
print(polity2Path)
# Out:
# Total path count: 		195.0
# [Unique / Sub paths / Total]: 	[194.0 / 1172303.0 / 1172498.0]
# Nodes:				21
# Edges:				326
# Max. path length:		218
# Avg path length:		87.61538461538461
# Paths of length k = 0		0.0 [ 0.0 / 17280.0 / 17280.0 ]
# Paths of length k = 1		1.0 [ 1.0 / 17084.0 / 17085.0 ]
# Paths of length k = 2		1.0 [ 1.0 / 16889.0 / 16890.0 ]
# Paths of length k = 3		1.0 [ 1.0 / 16695.0 / 16696.0 ]
# Paths of length k = 4		0.0 [ 0.0 / 16503.0 / 16503.0 ]
# Paths of length k = 5		0.0 [ 0.0 / 16311.0 / 16311.0 ]
# Paths of length k = 6		0.0 [ 0.0 / 16119.0 / 16119.0 ]
# Paths of length k = 7		2.0 [ 2.0 / 15925.0 / 15927.0 ]
# Paths of length k = 8		0.0 [ 0.0 / 15735.0 / 15735.0 ]
# Paths of length k = 9		0.0 [ 0.0 / 15545.0 / 15545.0 ]
# Paths of length k = 10		1.0 [ 1.0 / 15354.0 / 15355.0 ]
# Paths of length k = 11		1.0 [ 1.0 / 15164.0 / 15165.0 ]
# Paths of length k = 12		2.0 [ 2.0 / 14974.0 / 14976.0 ]
# Paths of length k = 13		1.0 [ 1.0 / 14787.0 / 14788.0 ]
# Paths of length k = 14		1.0 [ 1.0 / 14601.0 / 14602.0 ]
# Paths of length k = 15		0.0 [ 0.0 / 14417.0 / 14417.0 ]
# Paths of length k = 16		1.0 [ 1.0 / 14232.0 / 14233.0 ]
# Paths of length k = 17		0.0 [ 0.0 / 14049.0 / 14049.0 ]
# Paths of length k = 18		0.0 [ 0.0 / 13866.0 / 13866.0 ]
# Paths of length k = 19		0.0 [ 0.0 / 13683.0 / 13683.0 ]
# Paths of length k = 20		0.0 [ 0.0 / 13500.0 / 13500.0 ]
# Paths of length k = 21		0.0 [ 0.0 / 13317.0 / 13317.0 ]
# Paths of length k = 22		1.0 [ 1.0 / 13133.0 / 13134.0 ]
# Paths of length k = 23		1.0 [ 1.0 / 12950.0 / 12951.0 ]
# Paths of length k = 24		0.0 [ 0.0 / 12769.0 / 12769.0 ]
# Paths of length k = 25		3.0 [ 3.0 / 12585.0 / 12588.0 ]
# Paths of length k = 26		0.0 [ 0.0 / 12407.0 / 12407.0 ]
# Paths of length k = 27		14.0 [ 14.0 / 12215.0 / 12229.0 ]
# Paths of length k = 28		2.0 [ 2.0 / 12049.0 / 12051.0 ]
# Paths of length k = 29		0.0 [ 0.0 / 11887.0 / 11887.0 ]
# Paths of length k = 30		0.0 [ 0.0 / 11725.0 / 11725.0 ]
# Paths of length k = 31		0.0 [ 0.0 / 11563.0 / 11563.0 ]
# Paths of length k = 32		0.0 [ 0.0 / 11401.0 / 11401.0 ]
# Paths of length k = 33		0.0 [ 0.0 / 11239.0 / 11239.0 ]
# Paths of length k = 34		0.0 [ 0.0 / 11077.0 / 11077.0 ]
# Paths of length k = 35		0.0 [ 0.0 / 10915.0 / 10915.0 ]
# Paths of length k = 36		0.0 [ 0.0 / 10753.0 / 10753.0 ]
# Paths of length k = 37		0.0 [ 0.0 / 10591.0 / 10591.0 ]
# Paths of length k = 38		1.0 [ 1.0 / 10428.0 / 10429.0 ]
# Paths of length k = 39		2.0 [ 2.0 / 10265.0 / 10267.0 ]
# Paths of length k = 40		0.0 [ 0.0 / 10106.0 / 10106.0 ]
# Paths of length k = 41		2.0 [ 2.0 / 9945.0 / 9947.0 ]
# Paths of length k = 42		1.0 [ 1.0 / 9787.0 / 9788.0 ]
# Paths of length k = 43		6.0 [ 6.0 / 9625.0 / 9631.0 ]
# Paths of length k = 44		3.0 [ 3.0 / 9472.0 / 9475.0 ]
# Paths of length k = 45		3.0 [ 2.0 / 9322.0 / 9325.0 ]
# Paths of length k = 46		2.0 [ 2.0 / 9176.0 / 9178.0 ]
# Paths of length k = 47		3.0 [ 3.0 / 9031.0 / 9034.0 ]
# Paths of length k = 48		3.0 [ 3.0 / 8889.0 / 8892.0 ]
# Paths of length k = 49		0.0 [ 0.0 / 8753.0 / 8753.0 ]
# Paths of length k = 50		5.0 [ 5.0 / 8612.0 / 8617.0 ]
# Paths of length k = 51		0.0 [ 0.0 / 8481.0 / 8481.0 ]
# Paths of length k = 52		4.0 [ 4.0 / 8346.0 / 8350.0 ]
# Paths of length k = 53		2.0 [ 2.0 / 8217.0 / 8219.0 ]
# Paths of length k = 54		3.0 [ 3.0 / 8089.0 / 8092.0 ]
# Paths of length k = 55		5.0 [ 5.0 / 7962.0 / 7967.0 ]
# Paths of length k = 56		4.0 [ 4.0 / 7841.0 / 7845.0 ]
# Paths of length k = 57		4.0 [ 4.0 / 7724.0 / 7728.0 ]
# Paths of length k = 58		16.0 [ 16.0 / 7599.0 / 7615.0 ]
# Paths of length k = 59		1.0 [ 1.0 / 7505.0 / 7506.0 ]
# Paths of length k = 60		3.0 [ 3.0 / 7410.0 / 7413.0 ]
# Paths of length k = 61		1.0 [ 1.0 / 7320.0 / 7321.0 ]
# Paths of length k = 62		2.0 [ 2.0 / 7230.0 / 7232.0 ]
# Paths of length k = 63		0.0 [ 0.0 / 7144.0 / 7144.0 ]
# Paths of length k = 64		0.0 [ 0.0 / 7058.0 / 7058.0 ]
# Paths of length k = 65		1.0 [ 1.0 / 6971.0 / 6972.0 ]
# Paths of length k = 66		1.0 [ 1.0 / 6885.0 / 6886.0 ]
# Paths of length k = 67		2.0 [ 2.0 / 6799.0 / 6801.0 ]
# Paths of length k = 68		0.0 [ 0.0 / 6717.0 / 6717.0 ]
# Paths of length k = 69		2.0 [ 2.0 / 6633.0 / 6635.0 ]
# Paths of length k = 70		5.0 [ 5.0 / 6548.0 / 6553.0 ]
# Paths of length k = 71		4.0 [ 4.0 / 6469.0 / 6473.0 ]
# Paths of length k = 72		2.0 [ 2.0 / 6396.0 / 6398.0 ]
# Paths of length k = 73		1.0 [ 1.0 / 6326.0 / 6327.0 ]
# Paths of length k = 74		0.0 [ 0.0 / 6258.0 / 6258.0 ]
# Paths of length k = 75		0.0 [ 0.0 / 6190.0 / 6190.0 ]
# Paths of length k = 76		0.0 [ 0.0 / 6122.0 / 6122.0 ]
# Paths of length k = 77		0.0 [ 0.0 / 6054.0 / 6054.0 ]
# Paths of length k = 78		0.0 [ 0.0 / 5986.0 / 5986.0 ]
# Paths of length k = 79		0.0 [ 0.0 / 5918.0 / 5918.0 ]
# Paths of length k = 80		1.0 [ 1.0 / 5849.0 / 5850.0 ]
# Paths of length k = 81		0.0 [ 0.0 / 5782.0 / 5782.0 ]
# Paths of length k = 82		1.0 [ 1.0 / 5714.0 / 5715.0 ]
# Paths of length k = 83		0.0 [ 0.0 / 5648.0 / 5648.0 ]
# Paths of length k = 84		0.0 [ 0.0 / 5582.0 / 5582.0 ]
# Paths of length k = 85		0.0 [ 0.0 / 5516.0 / 5516.0 ]
# Paths of length k = 86		0.0 [ 0.0 / 5450.0 / 5450.0 ]
# Paths of length k = 87		1.0 [ 1.0 / 5383.0 / 5384.0 ]
# Paths of length k = 88		0.0 [ 0.0 / 5318.0 / 5318.0 ]
# Paths of length k = 89		0.0 [ 0.0 / 5253.0 / 5253.0 ]
# Paths of length k = 90		0.0 [ 0.0 / 5188.0 / 5188.0 ]
# Paths of length k = 91		1.0 [ 1.0 / 5122.0 / 5123.0 ]
# Paths of length k = 92		1.0 [ 1.0 / 5057.0 / 5058.0 ]
# Paths of length k = 93		0.0 [ 0.0 / 4994.0 / 4994.0 ]
# Paths of length k = 94		1.0 [ 1.0 / 4930.0 / 4931.0 ]
# Paths of length k = 95		0.0 [ 0.0 / 4868.0 / 4868.0 ]
# Paths of length k = 96		0.0 [ 0.0 / 4806.0 / 4806.0 ]
# Paths of length k = 97		1.0 [ 1.0 / 4743.0 / 4744.0 ]
# Paths of length k = 98		0.0 [ 0.0 / 4682.0 / 4682.0 ]
# Paths of length k = 99		0.0 [ 0.0 / 4621.0 / 4621.0 ]
# Paths of length k = 100		1.0 [ 1.0 / 4559.0 / 4560.0 ]
# Paths of length k = 101		2.0 [ 2.0 / 4497.0 / 4499.0 ]
# Paths of length k = 102		0.0 [ 0.0 / 4439.0 / 4439.0 ]
# Paths of length k = 103		0.0 [ 0.0 / 4381.0 / 4381.0 ]
# Paths of length k = 104		1.0 [ 1.0 / 4322.0 / 4323.0 ]
# Paths of length k = 105		1.0 [ 1.0 / 4264.0 / 4265.0 ]
# Paths of length k = 106		0.0 [ 0.0 / 4208.0 / 4208.0 ]
# Paths of length k = 107		0.0 [ 0.0 / 4152.0 / 4152.0 ]
# Paths of length k = 108		1.0 [ 1.0 / 4095.0 / 4096.0 ]
# Paths of length k = 109		0.0 [ 0.0 / 4040.0 / 4040.0 ]
# Paths of length k = 110		1.0 [ 1.0 / 3984.0 / 3985.0 ]
# Paths of length k = 111		1.0 [ 1.0 / 3929.0 / 3930.0 ]
# Paths of length k = 112		0.0 [ 0.0 / 3876.0 / 3876.0 ]
# Paths of length k = 113		0.0 [ 0.0 / 3823.0 / 3823.0 ]
# Paths of length k = 114		0.0 [ 0.0 / 3770.0 / 3770.0 ]
# Paths of length k = 115		1.0 [ 1.0 / 3716.0 / 3717.0 ]
# Paths of length k = 116		1.0 [ 1.0 / 3663.0 / 3664.0 ]
# Paths of length k = 117		1.0 [ 1.0 / 3611.0 / 3612.0 ]
# Paths of length k = 118		0.0 [ 0.0 / 3561.0 / 3561.0 ]
# Paths of length k = 119		0.0 [ 0.0 / 3511.0 / 3511.0 ]
# Paths of length k = 120		0.0 [ 0.0 / 3461.0 / 3461.0 ]
# Paths of length k = 121		0.0 [ 0.0 / 3411.0 / 3411.0 ]
# Paths of length k = 122		0.0 [ 0.0 / 3361.0 / 3361.0 ]
# Paths of length k = 123		0.0 [ 0.0 / 3311.0 / 3311.0 ]
# Paths of length k = 124		0.0 [ 0.0 / 3261.0 / 3261.0 ]
# Paths of length k = 125		0.0 [ 0.0 / 3211.0 / 3211.0 ]
# Paths of length k = 126		0.0 [ 0.0 / 3161.0 / 3161.0 ]
# Paths of length k = 127		0.0 [ 0.0 / 3111.0 / 3111.0 ]
# Paths of length k = 128		0.0 [ 0.0 / 3061.0 / 3061.0 ]
# Paths of length k = 129		0.0 [ 0.0 / 3011.0 / 3011.0 ]
# Paths of length k = 130		0.0 [ 0.0 / 2961.0 / 2961.0 ]
# Paths of length k = 131		0.0 [ 0.0 / 2911.0 / 2911.0 ]
# Paths of length k = 132		0.0 [ 0.0 / 2861.0 / 2861.0 ]
# Paths of length k = 133		0.0 [ 0.0 / 2811.0 / 2811.0 ]
# Paths of length k = 134		0.0 [ 0.0 / 2761.0 / 2761.0 ]
# Paths of length k = 135		0.0 [ 0.0 / 2711.0 / 2711.0 ]
# Paths of length k = 136		0.0 [ 0.0 / 2661.0 / 2661.0 ]
# Paths of length k = 137		0.0 [ 0.0 / 2611.0 / 2611.0 ]
# Paths of length k = 138		1.0 [ 1.0 / 2560.0 / 2561.0 ]
# Paths of length k = 139		0.0 [ 0.0 / 2511.0 / 2511.0 ]
# Paths of length k = 140		0.0 [ 0.0 / 2462.0 / 2462.0 ]
# Paths of length k = 141		0.0 [ 0.0 / 2413.0 / 2413.0 ]
# Paths of length k = 142		0.0 [ 0.0 / 2364.0 / 2364.0 ]
# Paths of length k = 143		0.0 [ 0.0 / 2315.0 / 2315.0 ]
# Paths of length k = 144		0.0 [ 0.0 / 2266.0 / 2266.0 ]
# Paths of length k = 145		0.0 [ 0.0 / 2217.0 / 2217.0 ]
# Paths of length k = 146		1.0 [ 1.0 / 2167.0 / 2168.0 ]
# Paths of length k = 147		0.0 [ 0.0 / 2119.0 / 2119.0 ]
# Paths of length k = 148		0.0 [ 0.0 / 2071.0 / 2071.0 ]
# Paths of length k = 149		2.0 [ 2.0 / 2021.0 / 2023.0 ]
# Paths of length k = 150		0.0 [ 0.0 / 1975.0 / 1975.0 ]
# Paths of length k = 151		1.0 [ 1.0 / 1928.0 / 1929.0 ]
# Paths of length k = 152		0.0 [ 0.0 / 1883.0 / 1883.0 ]
# Paths of length k = 153		0.0 [ 0.0 / 1838.0 / 1838.0 ]
# Paths of length k = 154		0.0 [ 0.0 / 1793.0 / 1793.0 ]
# Paths of length k = 155		0.0 [ 0.0 / 1748.0 / 1748.0 ]
# Paths of length k = 156		0.0 [ 0.0 / 1703.0 / 1703.0 ]
# Paths of length k = 157		1.0 [ 1.0 / 1657.0 / 1658.0 ]
# Paths of length k = 158		2.0 [ 2.0 / 1611.0 / 1613.0 ]
# Paths of length k = 159		0.0 [ 0.0 / 1569.0 / 1569.0 ]
# Paths of length k = 160		0.0 [ 0.0 / 1527.0 / 1527.0 ]
# Paths of length k = 161		1.0 [ 1.0 / 1484.0 / 1485.0 ]
# Paths of length k = 162		0.0 [ 0.0 / 1443.0 / 1443.0 ]
# Paths of length k = 163		1.0 [ 1.0 / 1401.0 / 1402.0 ]
# Paths of length k = 164		0.0 [ 0.0 / 1361.0 / 1361.0 ]
# Paths of length k = 165		0.0 [ 0.0 / 1321.0 / 1321.0 ]
# Paths of length k = 166		0.0 [ 0.0 / 1281.0 / 1281.0 ]
# Paths of length k = 167		0.0 [ 0.0 / 1241.0 / 1241.0 ]
# Paths of length k = 168		0.0 [ 0.0 / 1201.0 / 1201.0 ]
# Paths of length k = 169		0.0 [ 0.0 / 1161.0 / 1161.0 ]
# Paths of length k = 170		1.0 [ 1.0 / 1120.0 / 1121.0 ]
# Paths of length k = 171		1.0 [ 1.0 / 1080.0 / 1081.0 ]
# Paths of length k = 172		0.0 [ 0.0 / 1042.0 / 1042.0 ]
# Paths of length k = 173		1.0 [ 1.0 / 1003.0 / 1004.0 ]
# Paths of length k = 174		1.0 [ 1.0 / 965.0 / 966.0 ]
# Paths of length k = 175		1.0 [ 1.0 / 928.0 / 929.0 ]
# Paths of length k = 176		0.0 [ 0.0 / 893.0 / 893.0 ]
# Paths of length k = 177		0.0 [ 0.0 / 858.0 / 858.0 ]
# Paths of length k = 178		1.0 [ 1.0 / 822.0 / 823.0 ]
# Paths of length k = 179		2.0 [ 2.0 / 786.0 / 788.0 ]
# Paths of length k = 180		1.0 [ 1.0 / 753.0 / 754.0 ]
# Paths of length k = 181		0.0 [ 0.0 / 722.0 / 722.0 ]
# Paths of length k = 182		1.0 [ 1.0 / 690.0 / 691.0 ]
# Paths of length k = 183		0.0 [ 0.0 / 660.0 / 660.0 ]
# Paths of length k = 184		0.0 [ 0.0 / 630.0 / 630.0 ]
# Paths of length k = 185		0.0 [ 0.0 / 600.0 / 600.0 ]
# Paths of length k = 186		1.0 [ 1.0 / 569.0 / 570.0 ]
# Paths of length k = 187		1.0 [ 1.0 / 539.0 / 540.0 ]
# Paths of length k = 188		3.0 [ 3.0 / 508.0 / 511.0 ]
# Paths of length k = 189		0.0 [ 0.0 / 483.0 / 483.0 ]
# Paths of length k = 190		0.0 [ 0.0 / 458.0 / 458.0 ]
# Paths of length k = 191		0.0 [ 0.0 / 433.0 / 433.0 ]
# Paths of length k = 192		1.0 [ 1.0 / 407.0 / 408.0 ]
# Paths of length k = 193		2.0 [ 2.0 / 381.0 / 383.0 ]
# Paths of length k = 194		1.0 [ 1.0 / 358.0 / 359.0 ]
# Paths of length k = 195		2.0 [ 2.0 / 335.0 / 337.0 ]
# Paths of length k = 196		0.0 [ 0.0 / 316.0 / 316.0 ]
# Paths of length k = 197		0.0 [ 0.0 / 297.0 / 297.0 ]
# Paths of length k = 198		1.0 [ 1.0 / 277.0 / 278.0 ]
# Paths of length k = 199		1.0 [ 1.0 / 258.0 / 259.0 ]
# Paths of length k = 200		1.0 [ 1.0 / 240.0 / 241.0 ]
# Paths of length k = 201		0.0 [ 0.0 / 224.0 / 224.0 ]
# Paths of length k = 202		0.0 [ 0.0 / 208.0 / 208.0 ]
# Paths of length k = 203		0.0 [ 0.0 / 192.0 / 192.0 ]
# Paths of length k = 204		1.0 [ 1.0 / 175.0 / 176.0 ]
# Paths of length k = 205		0.0 [ 0.0 / 160.0 / 160.0 ]
# Paths of length k = 206		0.0 [ 0.0 / 145.0 / 145.0 ]
# Paths of length k = 207		2.0 [ 2.0 / 128.0 / 130.0 ]
# Paths of length k = 208		0.0 [ 0.0 / 115.0 / 115.0 ]
# Paths of length k = 209		0.0 [ 0.0 / 102.0 / 102.0 ]
# Paths of length k = 210		0.0 [ 0.0 / 89.0 / 89.0 ]
# Paths of length k = 211		1.0 [ 1.0 / 75.0 / 76.0 ]
# Paths of length k = 212		1.0 [ 1.0 / 62.0 / 63.0 ]
# Paths of length k = 213		1.0 [ 1.0 / 50.0 / 51.0 ]
# Paths of length k = 214		2.0 [ 2.0 / 38.0 / 40.0 ]
# Paths of length k = 215		0.0 [ 0.0 / 30.0 / 30.0 ]
# Paths of length k = 216		0.0 [ 0.0 / 22.0 / 22.0 ]
# Paths of length k = 217		2.0 [ 2.0 / 12.0 / 14.0 ]
# Paths of length k = 218		6.0 [ 6.0 / 0.0 / 6.0 ]

# %% [markdown]
# ### Bayes Factor

# %%
from paths import Paths

from bayes_multi_order_model_1 import opt_order_bayes_factors, probability_of_orders
from constraint import NetworkConstraint

# %%
max_order = 2 # max order that we are testing: the paths are of length 2, so higher than two does not make any sense, as we do not have any evidence for it.
optimal_order, loglikelihoods = opt_order_bayes_factors(pathway_data,max_order = max_order, nodes = nodes, constraint = constraint, eps = eps)
probability_of_each_order = probability_of_orders(loglikelihoods)
print(optimal_order)
print(loglikelihoods)
print(probability_of_each_order)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b191b3e708f8> in <module>
#       1 max_order = 2 # max order that we are testing: the paths are of length 2, so higher than two does not make any sense, as we do not have any evidence for it.
# ----> 2 optimal_order, loglikelihoods = opt_order_bayes_factors(pathway_data,max_order = max_order, nodes = nodes, constraint = constraint, eps = eps)
#       3 probability_of_each_order = probability_of_orders(loglikelihoods)
#       4 print(optimal_order)
#       5 print(loglikelihoods)
#
# NameError: name 'pathway_data' is not defined
